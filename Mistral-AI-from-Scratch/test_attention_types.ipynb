# %%
from xformers.ops.fmha.attn_bias import (
    BlockDiagonalCausalMask,
    BlockDiagonalCausalWithOffsetPaddedKeysMask,
    BlockDiagonalMask,
)

import pandas as pd

# %%
# Define coloring scheme for visualization
highlight_dict = {0.0: '#68A357', float('-inf'): '#C97064'}

def highlight_cells(value):
    return f'background-color: {highlight_dict.get(value, "")}'

# %%
# Example 1: BlockDiagonalCausalMask with Sliding Window

# Example prompts: 4, 6, and 5 tokens respectively
sequence_lengths = [4, 6, 5]
window_size = 2

causal_mask = BlockDiagonalCausalMask.from_seqlens(sequence_lengths).make_local_attention(window_size)

batch_dim = 1
total_tokens = sum(sequence_lengths)
mask_tensor = causal_mask.materialize((batch_dim, total_tokens, total_tokens))

df_mask = pd.DataFrame(mask_tensor[0].numpy())
df_mask.style.applymap(highlight_cells)
# Out:
# C:\Users\sayed\AppData\Local\Temp\ipykernel_38572\484256342.py:14: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   df_mask.style.applymap(highlight_cells)
# <style type="text/css">
# #T_d7c86_row0_col0, #T_d7c86_row1_col0, #T_d7c86_row1_col1, #T_d7c86_row2_col1, #T_d7c86_row2_col2, #T_d7c86_row3_col2, #T_d7c86_row3_col3, #T_d7c86_row4_col4, #T_d7c86_row5_col4, #T_d7c86_row5_col5, #T_d7c86_row6_col5, #T_d7c86_row6_col6, #T_d7c86_row7_col6, #T_d7c86_row7_col7, #T_d7c86_row8_col7, #T_d7c86_row8_col8, #T_d7c86_row9_col8, #T_d7c86_row9_col9, #T_d7c86_row10_col10, #T_d7c86_row11_col10, #T_d7c86_row11_col11, #T_d7c86_row12_col11, #T_d7c86_row12_col12, #T_d7c86_row13_col12, #T_d7c86_row13_col13, #T_d7c86_row14_col13, #T_d7c86_row14_col14 {
#   background-color: #68A357;
# }
# #T_d7c86_row0_col1, #T_d7c86_row0_col2, #T_d7c86_row0_col3, #T_d7c86_row0_col4, #T_d7c86_row0_col5, #T_d7c86_row0_col6, #T_d7c86_row0_col7, #T_d7c86_row0_col8, #T_d7c86_row0_col9, #T_d7c86_row0_col10, #T_d7c86_row0_col11, #T_d7c86_row0_col12, #T_d7c86_row0_col13, #T_d7c86_row0_col14, #T_d7c86_row1_col2, #T_d7c86_row1_col3, #T_d7c86_row1_col4, #T_d7c86_row1_col5, #T_d7c86_row1_col6, #T_d7c86_row1_col7, #T_d7c86_row1_col8, #T_d7c86_row1_col9, #T_d7c86_row1_col10, #T_d7c86_row1_col11, #T_d7c86_row1_col12, #T_d7c86_row1_col13, #T_d7c86_row1_col14, #T_d7c86_row2_col0, #T_d7c86_row2_col3, #T_d7c86_row2_col4, #T_d7c86_row2_col5, #T_d7c86_row2_col6, #T_d7c86_row2_col7, #T_d7c86_row2_col8, #T_d7c86_row2_col9, #T_d7c86_row2_col10, #T_d7c86_row2_col11, #T_d7c86_row2_col12, #T_d7c86_row2_col13, #T_d7c86_row2_col14, #T_d7c86_row3_col0, #T_d7c86_row3_col1, #T_d7c86_row3_col4, #T_d7c86_row3_col5, #T_d7c86_row3_col6, #T_d7c86_row3_col7, #T_d7c86_row3_col8, #T_d7c86_row3_col9, #T_d7c86_row3_col10, #T_d7c86_row3_col11, #T_d7c86_row3_col12, #T_d7c86_row3_col13, #T_d7c86_row3_col14, #T_d7c86_row4_col0, #T_d7c86_row4_col1, #T_d7c86_row4_col2, #T_d7c86_row4_col3, #T_d7c86_row4_col5, #T_d7c86_row4_col6, #T_d7c86_row4_col7, #T_d7c86_row4_col8, #T_d7c86_row4_col9, #T_d7c86_row4_col10, #T_d7c86_row4_col11, #T_d7c86_row4_col12, #T_d7c86_row4_col13, #T_d7c86_row4_col14, #T_d7c86_row5_col0, #T_d7c86_row5_col1, #T_d7c86_row5_col2, #T_d7c86_row5_col3, #T_d7c86_row5_col6, #T_d7c86_row5_col7, #T_d7c86_row5_col8, #T_d7c86_row5_col9, #T_d7c86_row5_col10, #T_d7c86_row5_col11, #T_d7c86_row5_col12, #T_d7c86_row5_col13, #T_d7c86_row5_col14, #T_d7c86_row6_col0, #T_d7c86_row6_col1, #T_d7c86_row6_col2, #T_d7c86_row6_col3, #T_d7c86_row6_col4, #T_d7c86_row6_col7, #T_d7c86_row6_col8, #T_d7c86_row6_col9, #T_d7c86_row6_col10, #T_d7c86_row6_col11, #T_d7c86_row6_col12, #T_d7c86_row6_col13, #T_d7c86_row6_col14, #T_d7c86_row7_col0, #T_d7c86_row7_col1, #T_d7c86_row7_col2, #T_d7c86_row7_col3, #T_d7c86_row7_col4, #T_d7c86_row7_col5, #T_d7c86_row7_col8, #T_d7c86_row7_col9, #T_d7c86_row7_col10, #T_d7c86_row7_col11, #T_d7c86_row7_col12, #T_d7c86_row7_col13, #T_d7c86_row7_col14, #T_d7c86_row8_col0, #T_d7c86_row8_col1, #T_d7c86_row8_col2, #T_d7c86_row8_col3, #T_d7c86_row8_col4, #T_d7c86_row8_col5, #T_d7c86_row8_col6, #T_d7c86_row8_col9, #T_d7c86_row8_col10, #T_d7c86_row8_col11, #T_d7c86_row8_col12, #T_d7c86_row8_col13, #T_d7c86_row8_col14, #T_d7c86_row9_col0, #T_d7c86_row9_col1, #T_d7c86_row9_col2, #T_d7c86_row9_col3, #T_d7c86_row9_col4, #T_d7c86_row9_col5, #T_d7c86_row9_col6, #T_d7c86_row9_col7, #T_d7c86_row9_col10, #T_d7c86_row9_col11, #T_d7c86_row9_col12, #T_d7c86_row9_col13, #T_d7c86_row9_col14, #T_d7c86_row10_col0, #T_d7c86_row10_col1, #T_d7c86_row10_col2, #T_d7c86_row10_col3, #T_d7c86_row10_col4, #T_d7c86_row10_col5, #T_d7c86_row10_col6, #T_d7c86_row10_col7, #T_d7c86_row10_col8, #T_d7c86_row10_col9, #T_d7c86_row10_col11, #T_d7c86_row10_col12, #T_d7c86_row10_col13, #T_d7c86_row10_col14, #T_d7c86_row11_col0, #T_d7c86_row11_col1, #T_d7c86_row11_col2, #T_d7c86_row11_col3, #T_d7c86_row11_col4, #T_d7c86_row11_col5, #T_d7c86_row11_col6, #T_d7c86_row11_col7, #T_d7c86_row11_col8, #T_d7c86_row11_col9, #T_d7c86_row11_col12, #T_d7c86_row11_col13, #T_d7c86_row11_col14, #T_d7c86_row12_col0, #T_d7c86_row12_col1, #T_d7c86_row12_col2, #T_d7c86_row12_col3, #T_d7c86_row12_col4, #T_d7c86_row12_col5, #T_d7c86_row12_col6, #T_d7c86_row12_col7, #T_d7c86_row12_col8, #T_d7c86_row12_col9, #T_d7c86_row12_col10, #T_d7c86_row12_col13, #T_d7c86_row12_col14, #T_d7c86_row13_col0, #T_d7c86_row13_col1, #T_d7c86_row13_col2, #T_d7c86_row13_col3, #T_d7c86_row13_col4, #T_d7c86_row13_col5, #T_d7c86_row13_col6, #T_d7c86_row13_col7, #T_d7c86_row13_col8, #T_d7c86_row13_col9, #T_d7c86_row13_col10, #T_d7c86_row13_col11, #T_d7c86_row13_col14, #T_d7c86_row14_col0, #T_d7c86_row14_col1, #T_d7c86_row14_col2, #T_d7c86_row14_col3, #T_d7c86_row14_col4, #T_d7c86_row14_col5, #T_d7c86_row14_col6, #T_d7c86_row14_col7, #T_d7c86_row14_c ...
#   background-color: #C97064;
# }
# </style>
# <table id="T_d7c86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7c86_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d7c86_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_d7c86_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_d7c86_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_d7c86_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_d7c86_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_d7c86_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_d7c86_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_d7c86_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_d7c86_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_d7c86_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_d7c86_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_d7c86_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_d7c86_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_d7c86_level0_col14" class="col_heading level0 col14" >14</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7c86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d7c86_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_d7c86_row0_col1" class="data row0 col1" >-inf</td>
#       <td id="T_d7c86_row0_col2" class="data row0 col2" >-inf</td>
#       <td id="T_d7c86_row0_col3" class="data row0 col3" >-inf</td>
#       <td id="T_d7c86_row0_col4" class="data row0 col4" >-inf</td>
#       <td id="T_d7c86_row0_col5" class="data row0 col5" >-inf</td>
#       <td id="T_d7c86_row0_col6" class="data row0 col6" >-inf</td>
#       <td id="T_d7c86_row0_col7" class="data row0 col7" >-inf</td>
#       <td id="T_d7c86_row0_col8" class="data row0 col8" >-inf</td>
#       <td id="T_d7c86_row0_col9" class="data row0 col9" >-inf</td>
#       <td id="T_d7c86_row0_col10" class="data row0 col10" >-inf</td>
#       <td id="T_d7c86_row0_col11" class="data row0 col11" >-inf</td>
#       <td id="T_d7c86_row0_col12" class="data row0 col12" >-inf</td>
#       <td id="T_d7c86_row0_col13" class="data row0 col13" >-inf</td>
#       <td id="T_d7c86_row0_col14" class="data row0 col14" >-inf</td>
#     </tr>
#     <tr>
#       <th id="T_d7c86_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d7c86_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_d7c86_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_d7c86_row1_col2" class="data row1 col2" >-inf</td>
#       <td id="T_d7c86_row1_col3" class="data row1 col3" >-inf</td>
#       <td id="T_d7c86_row1_col4" class="data row1 col4" >-inf</td>
#       <td id="T_d7c86_row1_col5" class="data row1 col5" >-inf</td>
#       <td id="T_d7c86_row1_col6" class="data row1 col6" >-inf</td>
#       <td id="T_d7c86_row1_col7" class="data row1 col7" >-inf</td>
#       <td id="T_d7c86_row1_col8" class="data row1 col8" >-inf</td>
#       <td id="T_d7c86_row1_col9" class="data row1 col9" >-inf</td>
#       <td id="T_d7c86_row1_col10" class="data row1 col10" >-inf</td>
#       <td id="T_d7c86_row1_col11" class="data row1 col

# %%
# Example 2: BlockDiagonalMask for prefill (queries and KV lengths differ)

query_lengths = [2, 4]
kv_lengths = [8, 5]   # For example: first prompt = 2 queries, 8 kv; second = 4 queries, 5 kv
window_size = 2

bd_mask = BlockDiagonalMask.from_seqlens(query_lengths, kv_lengths).make_local_attention_from_bottomright(window_size)

batch_dim = 1
q_total = sum(query_lengths)
kv_total = sum(kv_lengths)

mask_tensor = bd_mask.materialize((batch_dim, q_total, kv_total))

df_mask = pd.DataFrame(mask_tensor[0].numpy())
df_mask.style.applymap(highlight_cells)
# Out:
# C:\Users\sayed\AppData\Local\Temp\ipykernel_38572\1120142535.py:16: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   df_mask.style.applymap(highlight_cells)
# <style type="text/css">
# #T_284fb_row0_col0, #T_284fb_row0_col1, #T_284fb_row0_col2, #T_284fb_row0_col3, #T_284fb_row0_col4, #T_284fb_row0_col7, #T_284fb_row0_col8, #T_284fb_row0_col9, #T_284fb_row0_col10, #T_284fb_row0_col11, #T_284fb_row0_col12, #T_284fb_row1_col0, #T_284fb_row1_col1, #T_284fb_row1_col2, #T_284fb_row1_col3, #T_284fb_row1_col4, #T_284fb_row1_col5, #T_284fb_row1_col8, #T_284fb_row1_col9, #T_284fb_row1_col10, #T_284fb_row1_col11, #T_284fb_row1_col12, #T_284fb_row2_col0, #T_284fb_row2_col1, #T_284fb_row2_col2, #T_284fb_row2_col3, #T_284fb_row2_col4, #T_284fb_row2_col5, #T_284fb_row2_col6, #T_284fb_row2_col7, #T_284fb_row2_col10, #T_284fb_row2_col11, #T_284fb_row2_col12, #T_284fb_row3_col0, #T_284fb_row3_col1, #T_284fb_row3_col2, #T_284fb_row3_col3, #T_284fb_row3_col4, #T_284fb_row3_col5, #T_284fb_row3_col6, #T_284fb_row3_col7, #T_284fb_row3_col8, #T_284fb_row3_col11, #T_284fb_row3_col12, #T_284fb_row4_col0, #T_284fb_row4_col1, #T_284fb_row4_col2, #T_284fb_row4_col3, #T_284fb_row4_col4, #T_284fb_row4_col5, #T_284fb_row4_col6, #T_284fb_row4_col7, #T_284fb_row4_col8, #T_284fb_row4_col9, #T_284fb_row4_col12, #T_284fb_row5_col0, #T_284fb_row5_col1, #T_284fb_row5_col2, #T_284fb_row5_col3, #T_284fb_row5_col4, #T_284fb_row5_col5, #T_284fb_row5_col6, #T_284fb_row5_col7, #T_284fb_row5_col8, #T_284fb_row5_col9, #T_284fb_row5_col10 {
#   background-color: #C97064;
# }
# #T_284fb_row0_col5, #T_284fb_row0_col6, #T_284fb_row1_col6, #T_284fb_row1_col7, #T_284fb_row2_col8, #T_284fb_row2_col9, #T_284fb_row3_col9, #T_284fb_row3_col10, #T_284fb_row4_col10, #T_284fb_row4_col11, #T_284fb_row5_col11, #T_284fb_row5_col12 {
#   background-color: #68A357;
# }
# </style>
# <table id="T_284fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_284fb_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_284fb_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_284fb_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_284fb_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_284fb_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_284fb_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_284fb_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_284fb_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_284fb_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_284fb_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_284fb_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_284fb_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_284fb_level0_col12" class="col_heading level0 col12" >12</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_284fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_284fb_row0_col0" class="data row0 col0" >-inf</td>
#       <td id="T_284fb_row0_col1" class="data row0 col1" >-inf</td>
#       <td id="T_284fb_row0_col2" class="data row0 col2" >-inf</td>
#       <td id="T_284fb_row0_col3" class="data row0 col3" >-inf</td>
#       <td id="T_284fb_row0_col4" class="data row0 col4" >-inf</td>
#       <td id="T_284fb_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_284fb_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_284fb_row0_col7" class="data row0 col7" >-inf</td>
#       <td id="T_284fb_row0_col8" class="data row0 col8" >-inf</td>
#       <td id="T_284fb_row0_col9" class="data row0 col9" >-inf</td>
#       <td id="T_284fb_row0_col10" class="data row0 col10" >-inf</td>
#       <td id="T_284fb_row0_col11" class="data row0 col11" >-inf</td>
#       <td id="T_284fb_row0_col12" class="data row0 col12" >-inf</td>
#     </tr>
#     <tr>
#       <th id="T_284fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_284fb_row1_col0" class="data row1 col0" >-inf</td>
#       <td id="T_284fb_row1_col1" class="data row1 col1" >-inf</td>
#       <td id="T_284fb_row1_col2" class="data row1 col2" >-inf</td>
#       <td id="T_284fb_row1_col3" class="data row1 col3" >-inf</td>
#       <td id="T_284fb_row1_col4" class="data row1 col4" >-inf</td>
#       <td id="T_284fb_row1_col5" class="data row1 col5" >-inf</td>
#       <td id="T_284fb_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_284fb_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_284fb_row1_col8" class="data row1 col8" >-inf</td>
#       <td id="T_284fb_row1_col9" class="data row1 col9" >-inf</td>
#       <td id="T_284fb_row1_col10" class="data row1 col10" >-inf</td>
#       <td id="T_284fb_row1_col11" class="data row1 col11" >-inf</td>
#       <td id="T_284fb_row1_col12" class="data row1 col12" >-inf</td>
#     </tr>
#     <tr>
#       <th id="T_284fb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_284fb_row2_col0" class="data row2 col0" >-inf</td>
#       <td id="T_284fb_row2_col1" class="data row2 col1" >-inf</td>
#       <td id="T_284fb_row2_col2" class="data row2 col2" >-inf</td>
#       <td id="T_284fb_row2_col3" class="data row2 col3" >-inf</td>
#       <td id="T_284fb_row2_col4" class="data row2 col4" >-inf</td>
#       <td id="T_284fb_row2_col5" class="data row2 col5" >-inf</td>
#       <td id="T_284fb_row2_col6" class="data row2 col6" >-inf</td>
#       <td id="T_284fb_row2_col7" class="data row2 col7" >-inf</td>
#       <td id="T_284fb_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_284fb_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_284fb_row2_col10" class="data row2 col10" >-inf</td>
#       <td id="T_284fb_row2_col11" class="data row2 col11" >-inf</td>
#       <td id="T_284fb_row2_col12" class="data row2 col12" >-inf</td>
#     </tr>
#     <tr>
#       <th id="T_284fb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_284fb_row3_col0" class="data row3 col0" >-inf</td>
#       <td id="T_284fb_row3_col1" class="data row3 col1" >-inf</td>
#       <td id="T_284fb_row3_col2" class="data row3 col2" >-inf</td>
#       <td id="T_284fb_row3_col3" class="data row3 col3" >-inf</td>
#       <td id="T_284fb_row3_col4" class="data row3 col4" >-inf</td>
#       <td id="T_284fb_row3_col5" class="data row3 col5" >-inf</td>
#       <td id="T_284fb_row3_col6" class="data row3 col6" >-inf</td>
#       <td id="T_284fb_row3_col7" class="data row3 col7" >-inf</td>
#       <td id="T_284fb_row3_col8" class="data row3 col8" >-inf</td>
#       <td id="T_284fb_row3_col9" class="data row3 col9" >0.000000</td>
#       <td id="T_284fb_row3_col10" class="data row3 col10" >0.000000</td>
#       <td id="T_284fb_row3_col11" class="data row3 col11" >-inf</td>
#       <td id="T_284fb_row3_col12" class="data row3 col12" >-inf</td>
#     </tr>
#     <tr>
#       <th id="T_284fb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_284fb_row4_col0" class="data row4 col0" >-inf</td>
#       <td id="T_284fb_row4_col1" class="data row4 col1" >-inf</td>
#       <td id="T_284fb_row4_col2" class="data row4 col2" >-inf</td>
#       <td id="T_284fb_row4_col3" class="data row4 col3" >-inf</td>
#       <td id="T_284fb_row4_col4" class="data row4 col4" >-inf</td>
#       <td id="T_284fb_row4_col5" class="data row4 col5" >-inf</td>
#       <td id="T_284fb_row4_col6" class="data row4 col6" >-inf</td>
#       <td id="T_284fb_row4_col7" class="data row4 col7" >-inf</td>
#       <td id="T_284fb_row4_col8" class="data row4 col8" >-inf</td>
#       <td id="T_284fb_row4_col9" class="data row4 col9" >-inf</td>
#       <td id="T_284fb_row4_col10" class="data row4 col10" >0.000000</td>
#       <td id="T_284fb_row4_col11" class="data row4 col11" >0.000000</td>
#       <td id="T_284fb_row4_col12" class="data row4 col12" >-inf</td>
#     </tr>
#     <tr>
#       <th id="T_284fb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_284fb_row5_col0" class="data row5 col0" >-inf</td>
#       <td id="T_284fb_row5_col1" class="data row5 col1" >-inf</td>
#       <td id="T_284fb_row5_col2" class="data row5 col2" >-inf</td>
#       <td id="T_284fb_row5_col3" class="data r

# %%
# Example 3: BlockDiagonalCausalWithOffsetPaddedKeysMask for KV Cache Handling

q_len_list = [1, 1]
kv_actual_lengths = [4, 6]
kv_tensor_capacity = 8  # Fixed size tensor used in backend

offset_mask = BlockDiagonalCausalWithOffsetPaddedKeysMask.from_seqlens(
    q_seqlen=q_len_list,
    kv_padding=kv_tensor_capacity,
    kv_seqlen=kv_actual_lengths
)

batch_dim = 1
q_sum = sum(q_len_list)
kv_tensor_size = kv_tensor_capacity * len(kv_actual_lengths)

mask_tensor = offset_mask.materialize((batch_dim, q_sum, kv_tensor_size))

df_mask = pd.DataFrame(mask_tensor[0].numpy())
df_mask.style.applymap(highlight_cells)
# Out:
# C:\Users\sayed\AppData\Local\Temp\ipykernel_38572\3055986637.py:20: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   df_mask.style.applymap(highlight_cells)
# <style type="text/css">
# #T_9a6b1_row0_col0, #T_9a6b1_row0_col1, #T_9a6b1_row0_col2, #T_9a6b1_row0_col3, #T_9a6b1_row1_col8, #T_9a6b1_row1_col9, #T_9a6b1_row1_col10, #T_9a6b1_row1_col11, #T_9a6b1_row1_col12, #T_9a6b1_row1_col13 {
#   background-color: #68A357;
# }
# #T_9a6b1_row0_col4, #T_9a6b1_row0_col5, #T_9a6b1_row0_col6, #T_9a6b1_row0_col7, #T_9a6b1_row0_col8, #T_9a6b1_row0_col9, #T_9a6b1_row0_col10, #T_9a6b1_row0_col11, #T_9a6b1_row0_col12, #T_9a6b1_row0_col13, #T_9a6b1_row0_col14, #T_9a6b1_row0_col15, #T_9a6b1_row1_col0, #T_9a6b1_row1_col1, #T_9a6b1_row1_col2, #T_9a6b1_row1_col3, #T_9a6b1_row1_col4, #T_9a6b1_row1_col5, #T_9a6b1_row1_col6, #T_9a6b1_row1_col7, #T_9a6b1_row1_col14, #T_9a6b1_row1_col15 {
#   background-color: #C97064;
# }
# </style>
# <table id="T_9a6b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a6b1_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_9a6b1_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_9a6b1_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_9a6b1_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_9a6b1_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_9a6b1_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_9a6b1_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_9a6b1_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_9a6b1_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_9a6b1_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_9a6b1_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_9a6b1_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_9a6b1_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_9a6b1_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_9a6b1_level0_col14" class="col_heading level0 col14" >14</th>
#       <th id="T_9a6b1_level0_col15" class="col_heading level0 col15" >15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a6b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a6b1_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_9a6b1_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_9a6b1_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_9a6b1_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_9a6b1_row0_col4" class="data row0 col4" >-inf</td>
#       <td id="T_9a6b1_row0_col5" class="data row0 col5" >-inf</td>
#       <td id="T_9a6b1_row0_col6" class="data row0 col6" >-inf</td>
#       <td id="T_9a6b1_row0_col7" class="data row0 col7" >-inf</td>
#       <td id="T_9a6b1_row0_col8" class="data row0 col8" >-inf</td>
#       <td id="T_9a6b1_row0_col9" class="data row0 col9" >-inf</td>
#       <td id="T_9a6b1_row0_col10" class="data row0 col10" >-inf</td>
#       <td id="T_9a6b1_row0_col11" class="data row0 col11" >-inf</td>
#       <td id="T_9a6b1_row0_col12" class="data row0 col12" >-inf</td>
#       <td id="T_9a6b1_row0_col13" class="data row0 col13" >-inf</td>
#       <td id="T_9a6b1_row0_col14" class="data row0 col14" >-inf</td>
#       <td id="T_9a6b1_row0_col15" class="data row0 col15" >-inf</td>
#     </tr>
#     <tr>
#       <th id="T_9a6b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9a6b1_row1_col0" class="data row1 col0" >-inf</td>
#       <td id="T_9a6b1_row1_col1" class="data row1 col1" >-inf</td>
#       <td id="T_9a6b1_row1_col2" class="data row1 col2" >-inf</td>
#       <td id="T_9a6b1_row1_col3" class="data row1 col3" >-inf</td>
#       <td id="T_9a6b1_row1_col4" class="data row1 col4" >-inf</td>
#       <td id="T_9a6b1_row1_col5" class="data row1 col5" >-inf</td>
#       <td id="T_9a6b1_row1_col6" class="data row1 col6" >-inf</td>
#       <td id="T_9a6b1_row1_col7" class="data row1 col7" >-inf</td>
#       <td id="T_9a6b1_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_9a6b1_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_9a6b1_row1_col10" class="data row1 col10" >0.000000</td>
#       <td id="T_9a6b1_row1_col11" class="data row1 col11" >0.000000</td>
#       <td id="T_9a6b1_row1_col12" class="data row1 col12" >0.000000</td>
#       <td id="T_9a6b1_row1_col13" class="data row1 col13" >0.000000</td>
#       <td id="T_9a6b1_row1_col14" class="data row1 col14" >-inf</td>
#       <td id="T_9a6b1_row1_col15" class="data row1 col15" >-inf</td>
#     </tr>
#   </tbody>
# </table>
